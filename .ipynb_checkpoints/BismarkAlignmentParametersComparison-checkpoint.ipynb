# %%
#Subsampling from each fastq file and aligning with Bismark

# %%
# %%bash
#
# find /Volumes/web/seashell/bu-serine-wd/18-04-07/zr2096_*R1* \
# | xargs basename -s _s1_R1.fastq.gz | xargs -I{} /Users/Shelly/anaconda3/bin/bismark \
# --genome /Volumes/web/metacarcinus/Cvirginica/GENOMES/v300/Bismark_genome/ \
# --score_min L,0,-1.2 \
# -u 100000 \
# --non_directional \
# -1 /Volumes/web/seashell/bu-serine-wd/18-04-07/{}_s1_R1.fastq.gz \
# -2 /Volumes/web/seashell/bu-serine-wd/18-04-07/{}_s1_R2.fastq.gz \
# -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/
# Out:
# FastQ format assumed (by default)
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	55304
# Mapping efficiency:	55.3%
#
# Sequence pairs with no alignments under any condition:	27490
# Sequence pairs did not map uniquely:	17206
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	13863	((converted) top strand)
# GA/CT/CT:	13771	(complementary to (converted) top strand)
# GA/CT/GA:	13915	(complementary to (converted) bottom strand)
# CT/GA/GA:	13755	((converted) bottom strand)
#
# ...

# %%
#run deduplication

# %%
# %%bash
# /Users/Shelly/anaconda3/bin/deduplicate_bismark \
# --bam -p \
# /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/*.bam \
# -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/
# 2> /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/dedup.err
# Out:
# Now testing Bismark result file /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/zr2096_10_s1_R1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# ...

# %%
#create summary report of mapping efficiency and dedup.

# %%
# !cat /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/*PE_report.txt | grep 'Mapping\ efficiency\:' | cat - /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/*.deduplication_report.txt > /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/zr2096_mapping_dedup_summary.txt

# %%
# !mkdir /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3

# %%
#analysis with a tighter alignment score threshold

# %%
# %%bash
#
# find /Volumes/web/seashell/bu-serine-wd/18-04-07/zr2096_*R1* \
# | xargs basename -s _s1_R1.fastq.gz | xargs -I{} /Users/Shelly/anaconda3/bin/bismark \
# --genome /Volumes/web/metacarcinus/Cvirginica/GENOMES/v300/Bismark_genome/ \
# --score_min L,0,-0.6 \
# -u 100000 \
# --non_directional \
# -1 /Volumes/web/seashell/bu-serine-wd/18-04-07/{}_s1_R1.fastq.gz \
# -2 /Volumes/web/seashell/bu-serine-wd/18-04-07/{}_s1_R2.fastq.gz \
# -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/
# Out:
# FastQ format assumed (by default)
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	35458
# Mapping efficiency:	35.5%
#
# Sequence pairs with no alignments under any condition:	51704
# Sequence pairs did not map uniquely:	12838
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	8804	((converted) top strand)
# GA/CT/CT:	8916	(complementary to (converted) top strand)
# GA/CT/GA:	8935	(complementary to (converted) bottom strand)
# CT/GA/GA:	8803	((converted) bottom strand)
#
# ...

# %%
#run deduplicate on stricter alignment score threshold alignments

# %%
# %%bash
# /Users/Shelly/anaconda3/bin/deduplicate_bismark \
# --bam -p \
# /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/*.bam \
# -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/
# 2> /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/dedup.err
# Out:
# Now testing Bismark result file /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/zr2096_10_s1_R1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# ...

# %%
#create summary report of mapping efficiency and dedup.

# %%
# !cat /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/*PE_report.txt | grep 'Mapping\ efficiency\:' | cat - /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/*.deduplication_report.txt > /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/zr2096_mapping_dedup_summary.txt

# %%
#analysis with a looser alignment score threshold

# %%
# !mkdir /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4

# %%
# %%bash
#
# find /Volumes/web/seashell/bu-serine-wd/18-04-07/zr2096_*R1* \
# | xargs basename -s _s1_R1.fastq.gz | xargs -I{} /Users/Shelly/anaconda3/bin/bismark \
# --genome /Volumes/web/metacarcinus/Cvirginica/GENOMES/v300/Bismark_genome/ \
# --score_min L,0,-2 \
# -u 100000 \
# --non_directional \
# -1 /Volumes/web/seashell/bu-serine-wd/18-04-07/{}_s1_R1.fastq.gz \
# -2 /Volumes/web/seashell/bu-serine-wd/18-04-07/{}_s1_R2.fastq.gz \
# -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/
# Out:
# FastQ format assumed (by default)
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	79505
# Mapping efficiency:	79.5%
#
# Sequence pairs with no alignments under any condition:	213
# Sequence pairs did not map uniquely:	20282
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	20127	((converted) top strand)
# GA/CT/CT:	19634	(complementary to (converted) top strand)
# GA/CT/GA:	19795	(complementary to (converted) bottom strand)
# CT/GA/GA:	19949	((converted) bottom strand)
#
# ...

# %%
#run deduplicate on looser alignment score threshold alignments

# %%
# %%bash
# /Users/Shelly/anaconda3/bin/deduplicate_bismark \
# --bam -p \
# /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/*.bam \
# -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/
# 2> /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/dedup.err
# Out:
# Now testing Bismark result file /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/zr2096_10_s1_R1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# ...

# %%
#create summary report of mapping efficiency and dedup.

# %%
# !cat /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/*PE_report.txt | \
grep 'Mapping\ efficiency\:' | \
cat - /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/*.deduplication_report.txt > /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/zr2096_mapping_dedup_summary.txt

# %%
#Bismark analysis with fragment length threshold (60bp)

# %%
# !mkdir /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5

# %%
# %%bash
#
# find /Volumes/web/seashell/bu-serine-wd/18-04-07/zr2096_*R1* \
# | xargs basename -s _s1_R1.fastq.gz | xargs -I{} /Users/Shelly/anaconda3/bin/bismark \
# --genome /Volumes/web/metacarcinus/Cvirginica/GENOMES/v300/Bismark_genome/ \
# --score_min L,0,-1.2 \
# -u 100000 \
# -I 60 \
# --non_directional \
# -1 /Volumes/web/seashell/bu-serine-wd/18-04-07/{}_s1_R1.fastq.gz \
# -2 /Volumes/web/seashell/bu-serine-wd/18-04-07/{}_s1_R2.fastq.gz \
# -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/
# Out:
# FastQ format assumed (by default)
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	52694
# Mapping efficiency:	52.7%
#
# Sequence pairs with no alignments under any condition:	31468
# Sequence pairs did not map uniquely:	15838
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	13187	((converted) top strand)
# GA/CT/CT:	13076	(complementary to (converted) top strand)
# GA/CT/GA:	13300	(complementary to (converted) bottom strand)
# CT/GA/GA:	13131	((converted) bottom strand)
#
# ...

# %%
#run deduplicate on fragment length threshold (60bp) alignments

# %%
# %%bash
# /Users/Shelly/anaconda3/bin/deduplicate_bismark \
# --bam -p \
# /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/*.bam \
# -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/
# 2> /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/dedup.err
# Out:
# Now testing Bismark result file /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/zr2096_10_s1_R1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# ...

# %%
#create summary report of mapping efficiency and dedup.

# %%
# !cat /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/*PE_report.txt | \
grep 'Mapping\ efficiency\:' | \
cat - /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/*.deduplication_report.txt > /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/zr2096_mapping_dedup_summary.txt

# %%
#make a new directory for fragment length threshold (150bp)

# %%
mkdir /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6

# %%
#Bismark analysis with fragment length threshold (150bp)

# %%
# %%bash
#
# find /Volumes/web/seashell/bu-serine-wd/18-04-07/zr2096_*R1* \
# | xargs basename -s _s1_R1.fastq.gz | xargs -I{} /Users/Shelly/anaconda3/bin/bismark \
# --genome /Volumes/web/metacarcinus/Cvirginica/GENOMES/v300/Bismark_genome/ \
# --score_min L,0,-1.2 \
# -u 100000 \
# -I 150 \
# --non_directional \
# -1 /Volumes/web/seashell/bu-serine-wd/18-04-07/{}_s1_R1.fastq.gz \
# -2 /Volumes/web/seashell/bu-serine-wd/18-04-07/{}_s1_R2.fastq.gz \
# -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/
# Out:
# FastQ format assumed (by default)
# chr NC_035780.1 (65668440 bp)
# chr NC_035781.1 (61752955 bp)
# chr NC_035782.1 (77061148 bp)
# chr NC_035783.1 (59691872 bp)
# chr NC_035784.1 (98698416 bp)
# chr NC_035785.1 (51258098 bp)
# chr NC_035786.1 (57830854 bp)
# chr NC_035787.1 (75944018 bp)
# chr NC_035788.1 (104168038 bp)
# chr NC_035789.1 (32650045 bp)
# chr NC_007175.2 (17244 bp)
#
# Number of paired-end alignments with a unique best hit:	16486
# Mapping efficiency:	16.5%
#
# Sequence pairs with no alignments under any condition:	78915
# Sequence pairs did not map uniquely:	4599
# Sequence pairs which were discarded because genomic sequence could not be extracted:	0
#
# Number of sequence pairs with unique best (first) alignment came from the bowtie output:
# CT/GA/CT:	4115	((converted) top strand)
# GA/CT/CT:	4057	(complementary to (converted) top strand)
# GA/CT/GA:	4238	(complementary to (converted) bottom strand)
# CT/GA/GA:	4076	((converted) bottom strand)
#
# ...

# %%
#run deduplicate on fragment length threshold (150bp) alignments

# %%
# %%bash
# /Users/Shelly/anaconda3/bin/deduplicate_bismark \
# --bam -p \
# /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/*.bam \
# -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/
# 2> /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/dedup.err
# Out:
# Now testing Bismark result file /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/zr2096_10_s1_R1_bismark_bt2_pe.bam for positional sorting (which would be bad...)	skipping header line:	@HD	VN:1.0	SO:unsorted
# skipping header line:	@SQ	SN:NC_035780.1	LN:65668440
# skipping header line:	@SQ	SN:NC_035781.1	LN:61752955
# skipping header line:	@SQ	SN:NC_035782.1	LN:77061148
# skipping header line:	@SQ	SN:NC_035783.1	LN:59691872
# skipping header line:	@SQ	SN:NC_035784.1	LN:98698416
# skipping header line:	@SQ	SN:NC_035785.1	LN:51258098
# skipping header line:	@SQ	SN:NC_035786.1	LN:57830854
# skipping header line:	@SQ	SN:NC_035787.1	LN:75944018
# skipping header line:	@SQ	SN:NC_035788.1	LN:104168038
# skipping header line:	@SQ	SN:NC_035789.1	LN:32650045
# skipping header line:	@SQ	SN:NC_007175.2	LN:17244
# ...

# %%
#create summary report of mapping efficiency and dedup.

# %%
# !cat /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/*PE_report.txt | \
grep 'Mapping\ efficiency\:' | \
cat - /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/*.deduplication_report.txt > /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/zr2096_mapping_dedup_summary.txt

# %%
#combine summary mapping efficiency and dedup reports

# %%
# !paste -d' ' \
/Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/zr2096_mapping_dedup_summary.txt \
/Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/zr2096_mapping_dedup_summary.txt \
/Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/zr2096_mapping_dedup_summary.txt \
/Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/zr2096_mapping_dedup_summary.txt \
/Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/zr2096_mapping_dedup_summary.txt \
| grep 'Mapping\ efficiency\:\|removed' \
> /Volumes/web/metacarcinus/Cvirginica/bismarkASthreshold_comparison.txt

# %%
#clean up summary report file

# %%
#this first sed code replaces the string 'Mapping efficiency:' with nothing
#this 2nd sed code replaces the string 'Total number duplicated alignments removed:' with nothing
#this 3rd sed code replaces all spaces with nothing; awk code fixes spacing between columns
#next I opened the file in vim and added a header ('AS_06' = L,0,-0.6;'AS_12' = L,0,-1.2; 'AS_2' = L,0,-2; 'AS_12I60' = L,0,-12 & -I 60 ) and row names ('Lib[1-10]')
# !sed 's/Mapping\ efficiency\://g' /Volumes/web/metacarcinus/Cvirginica/bismarkASthreshold_comparison.txt | \
sed 's/Total\ number\ duplicated\ alignments\ removed\://g' | \
sed 's/ //g' | awk '{print $1,$2,$3,$4,$5}' > /Volumes/web/metacarcinus/Cvirginica/bismarkASthreshold_comparison_clean.txt

# %%
#compiling bam files and sorting

# %%
# %%bash
# find /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/*deduplicated.bam| \
# xargs basename -s _s1_R1_bismark_bt2_pe.deduplicated.bam | xargs -I{} /Users/Shelly/anaconda3/bin/samtools \
# sort /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/{}_s1_R1_bismark_bt2_pe.deduplicated.bam -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt2/{}_dedup.sorted.bam

# %%
# %%bash
# find /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/*deduplicated.bam| \
# xargs basename -s _s1_R1_bismark_bt2_pe.deduplicated.bam | xargs -I{} /Users/Shelly/anaconda3/bin/samtools \
# sort /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/{}_s1_R1_bismark_bt2_pe.deduplicated.bam -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt3/{}_dedup.sorted.bam

# %%
# %%bash
# find /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/*deduplicated.bam| \
# xargs basename -s _s1_R1_bismark_bt2_pe.deduplicated.bam | xargs -I{} /Users/Shelly/anaconda3/bin/samtools \
# sort /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/{}_s1_R1_bismark_bt2_pe.deduplicated.bam -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt4/{}_dedup.sorted.bam

# %%
# %%bash
# find /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/*deduplicated.bam| \
# xargs basename -s _s1_R1_bismark_bt2_pe.deduplicated.bam | xargs -I{} /Users/Shelly/anaconda3/bin/samtools \
# sort /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/{}_s1_R1_bismark_bt2_pe.deduplicated.bam -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt5/{}_dedup.sorted.bam

# %%
# %%bash
# find /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/*deduplicated.bam| \
# xargs basename -s _s1_R1_bismark_bt2_pe.deduplicated.bam | xargs -I{} /Users/Shelly/anaconda3/bin/samtools \
# sort /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/{}_s1_R1_bismark_bt2_pe.deduplicated.bam -o /Volumes/web/metacarcinus/Cvirginica/Bismark_attempt6/{}_dedup.sorted.bam
